# %%
#최초로 git clone 할 때 personal token 값으로 연결하기
#!git clone https://luckypapa81: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@github.com/luckypapa81/ku_dfe_group2.git

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/GitHub/ku_dfe_group2
# Out:
# /content/drive/MyDrive/Colab Notebooks/GitHub/ku_dfe_group2

# %%
# !git config --global user.email "luckypapa81@gmail.com"
# !git config --global user.name "luckypapa81"

# %%
# !git add .

# %%
# !git commit -m 'google colab과 github 연동 설정'
# Out:
# [master eb341dd] google colab과 github 연동 설정
#  1 file changed, 1 insertion(+)
#  create mode 100644 git_command_sample.ipynb

# %%
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.05 KiB | 268.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/luckypapa81/ku_dfe_group2.git
#    8f433fb..eb341dd  master -> master
